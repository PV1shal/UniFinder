# %%
import pandas as pd
import warnings
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import RocCurveDisplay
warnings.filterwarnings("ignore")

# %%
url = 'https://drive.google.com/file/d/1m0B-ur9NxnTPGuN_LjHL3mwN72ZYCZB3/view?usp=sharing'
url = 'https://drive.google.com/uc?id=' + url.split('/')[-2]
df_admitsFYI = pd.read_csv(url)

# %%
df_admitsFYI.head()
# Out:
#                        University  Status      Target Major         Term  \
# 0  Bowling Green State University  Reject  Computer Science    Fall 2015
# 1  Bowling Green State University   Admit  Computer Science  Spring 2017
# 2  Bowling Green State University   Admit  Computer Science    Fall 2016
# 3  Bowling Green State University  Reject  Computer Science    Fall 2016
# 4  Bowling Green State University   Admit  Computer Science  Spring 2016
#
#    GRE Verbal  GRE Quantitative  GRE Writing  GRE Total  TOEFL/IELTS  \
# 0       135.0             146.0          3.0      281.0          6.0
# 1       170.0             147.0          4.0      317.0        100.0
# 2         NaN               NaN          NaN        NaN          6.0
# 3       148.0             133.0          3.0      281.0          6.5
# 4       147.0             136.0          2.0      283.0          6.0
#
#                            UG College                UG Major    GPA  Papers  \
# 0  SIES Graduate School of Technology  Information Technology  56.00     NaN
# 1       thapathali engineering campus                     ECE  74.80     NaN
# 2           mic college of technology        Computer Science  60.00     NaN
# 3     Vellore Institute of Technology        Computer Science   7.23     NaN
# 4                    Gitam University        Computer Science   7.00     NaN
#
#   Work Exp
# 0     0 Mo
# 1     0 Mo
# 2     0 Mo
# 3     0 Mo
# 4     0 Mo

# %%
df_admitsFYI.describe()
# Out:
#          GRE Verbal  GRE Quantitative   GRE Writing     GRE Total  \
# count  37867.000000      37869.000000  34981.000000  37862.000000
# mean     160.844482        150.359951      3.394412    311.204902
# std        5.788238          6.813075      0.836266     10.669447
# min      130.000000        130.000000      0.000000    260.000000
# 25%      157.000000        146.000000      3.000000    304.000000
# 50%      161.000000        150.000000      3.500000    312.000000
# 75%      165.000000        155.000000      4.000000    319.000000
# max      170.000000        170.000000      6.000000    340.000000
#
#         TOEFL/IELTS           GPA        Papers
# count  37603.000000  38612.000000  14644.000000
# mean      82.039133     31.086302      0.322180
# std       40.134167     30.256490      0.752966
# min        0.000000      0.000000      0.000000
# 25%       85.000000      7.800000      0.000000
# 50%      100.000000      8.780000      0.000000
# 75%      108.000000     65.000000      0.000000
# max      120.000000    100.000000     11.000000

# %%
df_admitsFYI.dropna(subset=['GRE Verbal', 'GRE Quantitative', 'GRE Writing', 'GRE Total', 'GPA', ], inplace=True)

# %%
df_admitsFYI['Papers'].fillna(0.0, inplace=True)

# %%
terms_to_drop = [
    "Fall -1", "Nd 2015", "Summer 2013", "Summer 2013", "Spring 2007",
    "Summer 2015", "Spring 2008", "Summer 2011", "Fall 2005", "Nd 2013",
    "Spring 2009", "Spring -1", "-2"
]

# %%
df_admitsFYI = df_admitsFYI[~df_admitsFYI['Term'].isin(terms_to_drop)]

df_admitsFYI[['Season', 'Year']] = df_admitsFYI['Term'].str.split(' ', expand=True)

df_admitsFYI.drop(columns=['Term'], inplace=True)

# %%
df_admitsFYI['GPA'] = df_admitsFYI['GPA'].apply(lambda x: (x / 10) * 4 if pd.notnull(x) and x <=10 else (x / 100) * 4)

# %%
df_admitsFYI['Work Exp'] = df_admitsFYI['Work Exp'].str.replace(' Mo', '')

# %%
df_admitsFYI['Status'] = df_admitsFYI['Status'].map({'Admit': 1, 'Reject': 0})

# %%
df_admitsFYI['TOEFL'] = 0.0
df_admitsFYI['IELTS'] = 0.0

#filter TOEFL (val > 9)
df_admitsFYI.loc[df_admitsFYI['TOEFL/IELTS'] > 9, 'TOEFL'] = df_admitsFYI['TOEFL/IELTS']
#filter IELTS (val <= 9)
df_admitsFYI.loc[df_admitsFYI['TOEFL/IELTS'] <= 9, 'IELTS'] = df_admitsFYI['TOEFL/IELTS']

df_admitsFYI.drop(['TOEFL/IELTS'], axis=1, inplace=True)

# %%
display(df_admitsFYI.head(5))
# Out:
#                        University  Status      Target Major  GRE Verbal  \
# 0  Bowling Green State University       0  Computer Science       135.0
# 1  Bowling Green State University       1  Computer Science       170.0
# 3  Bowling Green State University       0  Computer Science       148.0
# 4  Bowling Green State University       1  Computer Science       147.0
# 5  Bowling Green State University       1  Computer Science       154.0
#
#    GRE Quantitative  GRE Writing  GRE Total  \
# 0             146.0          3.0      281.0
# 1             147.0          4.0      317.0
# 3             133.0          3.0      281.0
# 4             136.0          2.0      283.0
# 5             144.0          3.5      298.0
#
#                                         UG College                UG Major  \
# 0               SIES Graduate School of Technology  Information Technology
# 1                    thapathali engineering campus                     ECE
# 3                  Vellore Institute of Technology        Computer Science
# 4                                 Gitam University        Computer Science
# 5  Institute of Engineering & Science, IPS Academy        Computer Science
#
#      GPA  Papers Work Exp  Season  Year  TOEFL  IELTS
# 0  2.240     0.0        0    Fall  2015    0.0    6.0
# 1  2.992     0.0        0  Spring  2017  100.0    0.0
# 3  2.892     0.0        0    Fall  2016    0.0    6.5
# 4  2.800     0.0        0  Spring  2016    0.0    6.0
# 5  2.804     0.0        0    Fall  2017   97.0    0.0

# %% [markdown]
# Things to fix / do :
# 1. If Particular Unis and Majors have less than 5 / 10 records , drop them
# 2. Any particular university having any one of  Admit / Rejects only, drop them.

# %%
df= df_admitsFYI.copy()
uni_major_status_counts = df.groupby(['University', 'Target Major', 'Status']).size()
to_drop_status = uni_major_status_counts.groupby(level=[0,1]).size().eq(1).groupby(level=[0,1]).any()
to_drop_status_indices = to_drop_status[to_drop_status].index
df = df[~df.set_index(['University', 'Target Major']).index.isin(to_drop_status_indices)]
df.head()
# Out:
#                        University  Status      Target Major  GRE Verbal  \
# 0  Bowling Green State University       0  Computer Science       135.0
# 1  Bowling Green State University       1  Computer Science       170.0
# 3  Bowling Green State University       0  Computer Science       148.0
# 4  Bowling Green State University       1  Computer Science       147.0
# 5  Bowling Green State University       1  Computer Science       154.0
#
#    GRE Quantitative  GRE Writing  GRE Total  \
# 0             146.0          3.0      281.0
# 1             147.0          4.0      317.0
# 3             133.0          3.0      281.0
# 4             136.0          2.0      283.0
# 5             144.0          3.5      298.0
#
#                                         UG College                UG Major  \
# 0               SIES Graduate School of Technology  Information Technology
# 1                    thapathali engineering campus                     ECE
# 3                  Vellore Institute of Technology        Computer Science
# 4                                 Gitam University        Computer Science
# 5  Institute of Engineering & Science, IPS Academy        Computer Science
#
#      GPA  Papers Work Exp  Season  Year  TOEFL  IELTS
# 0  2.240     0.0        0    Fall  2015    0.0    6.0
# 1  2.992     0.0        0  Spring  2017  100.0    0.0
# 3  2.892     0.0        0    Fall  2016    0.0    6.5
# 4  2.800     0.0        0  Spring  2016    0.0    6.0
# 5  2.804     0.0        0    Fall  2017   97.0    0.0

# %% [markdown]
# ### VP NOTE LOOK INTO IT in the future
#
# Interesting observation by Allen

# %%
adf = df.groupby(['University', 'Target Major'])['Status'].count().reset_index()
adf=adf[adf['Status'] <4]
#value_drop = value_drop[['University','Target Major']].tolist()
# value_drop
adf
# Out:
#                                         University  \
# 187  George Washington University, Virginia Campus
# 188  George Washington University, Virginia Campus
# 190  George Washington University, Virginia Campus
# 191  George Washington University, Virginia Campus
# 227                             Harvard University
# 228                             Harvard University
# 254                      Illinois State University
# 278                          Iowa State University
# 279                          Iowa State University
# 284                       Johns Hopkins University
# 288                       Johns Hopkins University
# 296                        Kansas State University
# 304                            Lakehead University
# 306                               Lamar University
# 325                              Lehigh University
# 326                              Lehigh University
# 328        Louisiana State University, Baton Rouge
# 336             New Jersey Institute of Technology
# 405                      San Jose State University
# 412    South Dakota School of Mines and Technology
# 502            University of Pittsburgh, Johnstown
# 503            University of Pittsburgh, Johnstown
# 504            University of Pittsburgh, Johnstown
#
#                            Target Major  Status
# 187                      Bioinformatics       2
# 188                                EECS       2
# 190                 Information Systems       3
# 191       Telecommunication Engineering       3
# 227                        Architecture       3
# 228                      Bioinformatics       2
# 254              Information Technology       2
# 278              Engineering Management       3
# 279           Environmental Engineering       3
# 284                Chemical Engineering       2
# 288                                EECS       3
# 296                                EECS       2
# 304                                 MBA       3
# 306                Chemical Engineering       3
# 325  Management Science and Engineering       3
# 326           Manufacturing Engineering       2
# 328              Automotive Engineering       2
# 336                        Architecture       3
# 405              Information Technology       3
# 412              Electrical Engineering       2
# 502                    Computer Science       2
# 503              Electrical Engineering       2
# 504       Telecommunication Engineering       3

# %% [markdown]
# # VP Findings Starts Here

# %%
# Group by Uni then Major courses and print the count for number of records for each majors in each university
# ordered by the count in descending order

x = df.groupby(['University', 'Target Major']).size().sort_values(ascending=False)
for i in x.index:
    print(i, x[i])
# Out:
# ('Clemson University', 'Civil Engineering') 312
# ('Clemson University', 'Computer Science') 304
# ('University of Maryland, College Park', 'Mechanical Engineering') 300
# ('University of Maryland, College Park', 'Telecommunications Engineering') 300
# ('Clemson University', 'Mechanical Engineering') 296
# ('Clemson University', 'Industrial Engineering') 296
# ('University of Maryland, College Park', 'MIS') 292
# ('Clemson University', 'Electrical Engineering') 292
# ('Clemson University', 'Automotive Engineering') 288
# ('Clemson University', 'Computer Engineering') 284
# ('University of Maryland, College Park', 'Robotics') 280
# ('University of Maryland, College Park', 'Software Engineering') 260
# ('University of Maryland, College Park', 'Telecommunication Engineering') 216
# ('State University of New York, Buffalo', 'Robotics') 170
# ('Georgia Institute of Technology', 'Cyber Security') 166
# ('University of Maryland, College Park', 'Information Management') 160
# ('University of Colorado, Boulder', 'Telecommunications Engineering') 156
# ('George Mason University', 'Computer Science') 156
# ('Carnegie Mellon University', 'Chemical Engineering') 156
# ('Carnegie Mellon University', 'Data Science') 154
# ('University of Colorado, Boulder', 'Computer Science') 154
# ('Rutgers University, New Brunswick', 'Industrial and Systems Engineering') 154
# ('Columbia University', 'Mechanical Engineering') 154
# ('State University of New York, Binghamton', 'Computer Science') 154
# ('University of North Carolina, Charlotte', 'Information Technology') 154
# ('Purdue University, West Lafayette', 'Civil Engineering') 152
# ('California State University, Long Beach', 'Electrical Engineering') 152
# ('University of Maryland, College Park', 'Computer Science') 152
# ('Columbia University', 'Data Science') 152
# ('Georgia Institute of Technology', 'Industrial Engineering') 152
# ('Georgia Institute of Technology', 'Aerospace Engineering') 152
# ('California State University, Fresno', 'Electrical Engineering') 152
# ('Rutgers University, New Brunswick', 'Computer Science') 152
# ('University of North Carolina, Charlotte', 'Civil Engineering') 152
# ('State University of New York, Buffalo', 'Civil Engineering') 152
# ('Cleveland State University', 'Electrical Engineering') 150
# ('Illinios Institute of Technology, Chicago', 'MIS') 150
# ('Illinios Institute of Technology, Chicago', 'Computer Science') 150
# ('State University of New York, Buffalo', 'Data Science') 150
# ('Georgia State University', 'Computer Science') 150
# ('Georgia Institute of Technology', 'EECS') 150
# ('Georgia Institute of Technology', 'Civil Engineering') 150
# ('George Washington University', 'Computer Science') 148
# ('Georgia Institute of Technology', 'Computer Science') 148
# ('University of Maryland, College Park', 'Information Systems') 148
# ('George Washington University', 'Data Science') 148
# ('Columbia University', 'Electrical Engineering') 148
# ('University of North Carolina, Charlotte', 'Engineering Management') 148
# ('Illinios Institute of Technology, Chicago', 'Information Technology Management') 148
# ('Carnegie Mellon University', 'Cyber Security') 148
# ('State University of New York, Stony Brook', 'Computer Science') 148
# ('University of North Carolina, Charlotte', 'MIS') 148
# ('State University of New York, Buffalo', 'Computer Science') 148
# ('California State University, Fresno', 'Computer Science') 148
# ('Purdue University, West Lafayette', 'Mechanical Engineering') 148
# ('Purdue University, West Lafayette', 'Industrial Engineering') 148
# ('Purdue University, West Lafayette', 'Computer Science') 148
# ('State University of New York, Buffalo', 'MIS') 146
# ('Carnegie Mellon University', 'Robotics') 146
# ('Carnegie Mellon University', 'Mechanical Engineering') 146
# ('Georgia Institute of Technology', 'Data Analytics') 146
# ('State University of New York, Albany', 'Computer Science') 146
# ('Duke University', 'Engineering Management') 146
# ('University of North Carolina, Charlotte', 'Computer Science') 146
# ('Illinios Institute of Technology, Chicago', 'Mechanical Engineering') 146
# ('Illinios Institute of Technology, Chicago', 'Computer Engineering') 146
# ('Drexel University', 'Business Analytics') 144
# ('Florida State University', 'Computer Science') 144
# ('Illinios Institute of Technology, Chicago', 'Data Science') 144
# ('State University of New York, Buffalo', 'Mechanical Engineering') 144
# ('Rutgers University, New Brunswick', 'Information Technology') 144
# ('University of North Carolina, Charlotte', 'Data Science and Business Analytics') 144
# ('University of Colorado, Boulder', 'Mechanical Engineering') 144
# ('Carnegie Mellon University', 'Information Systems') 144
# ('University of Maryland, College Park', 'Business Analytics') 144
# ('Georgia Institute of Technology', 'Mechanical Engineering') 144
# ('Fairleigh Dickinson University', 'Computer Science') 142
# ('State University of New York, Binghamton', 'Industrial and Systems Engineering') 142
# ('California State University, Long Beach', 'Computer Science') 142
# ('Drexel University', 'Electrical Engineering') 142
# ('Illinios Institute of Technology, Chicago', 'Electrical Engineering') 142
# ('University of North Carolina, Charlotte', 'Mechanical Engineering') 142
# ('George Mason University', 'Information Systems') 142
# ('Carnegie Mellon University', 'Computer Science') 142
# ('Rutgers University, New Brunswick', 'Data Science') 142
# ('Purdue University, West Lafayette', 'Engineering Management') 142
# ('Georgia State University', 'Information Systems') 142
# ('Drexel University', 'Computer Science') 142
# ('George Mason University', 'Computer Engineering') 140
# ('Rutgers University, New Brunswick', 'Mechanical Engineering') 140
# ('University of Maryland, College Park', 'Human Computer Interaction') 140
# ('University of Colorado, Boulder', 'Civil Engineering') 140
# ('University of Colorado, Boulder', 'Electrical Engineering') 140
# ('State University of New York, Buffalo', 'Industrial Engineering') 140
# ('Columbia University', 'Management Science and Engineering') 140
# ('Carnegie Mellon University', 'Machine Learning') 140
# ('Carnegie Mellon University', 'Information Management and Systems') 140
# ('University of North Carolina, Charlotte', 'Electrical Engineering') 140
# ('Cleveland State University', 'Mechanical Engineering') 138
# ('Columbia University', 'Computer Science') 138
# ('Illinios Institute of Technology, Chicago', 'Civil Engineering') 138
# ('Purdue University, West Lafayette', 'Business Analytics and Information Syste') 138
# ('Simon Fraser University', 'Computing Science') 136
# ('State University of New York, Stony Brook', 'Mechanical Engineering') 136
# ('University of Maryland, College Park', 'Cyber Security') 136
# ('Delft University of Technology', 'Mechanical Engineering') 134
# ('Cleveland State University', 'Computer Science') 132
# ('George Mason University', 'Data Analytics') 130
# ('Purdue University, West Lafayette', 'Chemical Engineering') 130
# ('Carnegie Mellon University', 'Electrical Engineering') 128
# ('Rutgers University, New Brunswick', 'Electrical Engineering') 128
# ('Cleveland State University', 'Information Systems') 128
# ('Purdue University, West Lafayette', 'Electrical Engineering') 124
# ('Delft University of Technology', 'Aerospace Engineering') 122
# ('Duke University', 'Computer Science') 120
# ('Georgia State University', 'MIS') 120
# ('Purdue University, West Lafayette', 'EECS') 118
# ('State University of New York, Albany', 'Data Science') 118
# ('Carnegie Mellon University', 'EECS') 116
# ('State University of New York, Buffalo', 'Electrical Engineering') 116
# ('Columbia University', 'Industrial Engineering') 116
# ('Georgia Institute of Technology', 'Electrical Engineering') 114
# ('Purdue University, West Lafayette', 'Information Technology') 114
# ('State University of New York, Buffalo', 'Biomedical Engineering') 112
# ('Carnegie Mellon University', 'Software Engineering') 112
# ('University of Colorado, Boulder', 'Telecommunication Engineering') 112
# ('Florida Institute of Technology', 'Computer Science') 108
# ('University of Maryland, College Park', 'Electrical Engineering') 108
# ('Florida International University, Miami', 'Computer Science') 108
# ('Delft University of Technology', 'Electrical Engineering') 106
# ('State University of New York, Binghamton', 'Mechanical Engineering') 106
# ('California State University, Long Beach', 'Civil Engineering') 104
# ('Carnegie Mellon University', 'MIS') 102
# ('State University of New York, Stony Brook', 'Electrical Engineering') 102
# ('California State University, Long Beach', 'Mechanical Engineering') 100
# ('George Mason University', 'Cyber Security') 100
# ('Illinios Institute of Technology, Chicago', 'Cyber Security') 98
# ('Georgia Institute of Technology', 'Human Computer Interaction') 98
# ('Cleveland State University', 'Civil Engineering') 96
# ('Duke University', 'Biomedical Engineering') 96
# ('Clemson University', 'EECS') 96
# ('Simon Fraser University', 'Big Data') 96
# ('University of North Carolina, Charlotte', 'EECS') 96
# ('Cleveland State University', 'Software Engineering') 92
# ('University of Maryland, College Park', 'EECS') 90
# ('Dalhousie University', 'Computer Science') 90
# ('Carnegie Mellon University', 'Information Technology') 86
# ('Drexel University', 'Biomedical Engineering') 86
# ('State University of New York, Buffalo', 'Chemical Engineering') 86
# ('Georgia Institute of Technology', 'Supply Chain Management') 84
# ('Duke University', 'Business Analytics') 84
# ('Columbia University', 'Business Analytics') 84
# ('Georgia Institute of Technology', 'Chemical and Petroleum Engineering') 80
# ('Indiana University, Bloomington', 'Computer Science') 78
# ('University of Colorado, Boulder', 'EECS') 78
# ('Iowa State University', 'Civil Engineering') 77
# ('San Jose State University', 'Computer Engineering') 77
# ('San Jose State University', 'Computer Science') 77
# ('San Jose State University', 'Software Engineering') 77
# ('George Washington University', 'Engineering Management') 76
# ('Iowa State University', 'MIS') 76
# ('State University of New York, Binghamton', 'Electrical Engineering') 76
# ('Drexel University', 'Information Systems') 76
# ('Johns Hopkins University', 'Engineering Management') 76
# ('Illinios Institute of Technology, Chicago', 'Chemical Engineering') 76
# ('New Jersey Institute of Technology', 'Information Systems') 75
# ('Lehigh University', 'Industrial and Systems Engineering') 75
# ('New Jersey Institute of Technology', 'Data Science') 75
# ('Iowa State University', 'Mechanical Engineering') 75
# ('Iowa State University', 'Computer Science') 74
# ('George Washington University, Mount Vernon College', 'Computer Science') 74
# ('Indiana University - Purdue University, Indianapolis', 'Mechanical Engineering') 74
# ('George Mason University', 'Electrical Engineering') 74
# ('New Jersey Institute of Technology', 'Industrial Engineering') 74
# ('New Jersey Institute of Technology', 'MIS') 74
# ('Indiana University, Bloomington', 'MIS') 73
# ('Indiana University, Bloomington', 'Data Science') 73
# ('New Jersey Institute of Technology', 'Electrical Engineering') 73
# ('New Jersey Institute of Technology', 'Computer Engineering') 72
# ('Carnegie Mellon University', 'Biomedical Engineering') 72
# ('San Jose State University', 'Electrical Engineering') 72
# ('Johns Hopkins University', 'Computer Science') 72
# ('Purdue University, West Lafayette', 'Biomedical Engineering') 72
# ('Iowa State University', 'Computer Engineering') 72
# ('New Jersey Institute of Technology', 'Mechanical Engineering') 72
# ('Iowa State University', 'Industrial Engineering') 72
# ('Iowa State University', 'Electrical Engineering') 71
# ('Lamar University', 'Industrial Engineering') 71
# ('New Jersey Institute of Technology', 'Civil Engineering') 70
# ('Dalhousie University', 'Applied Computer Science') 70
# ('Kansas State University', 'Computer Science') 70
# ('New Jersey Institute of Technology', 'Computer Science') 69
# ('Kent State University', 'Computer Science') 69
# ('New Jersey Institute of Technology', 'Engineering Management') 68
# ('Johns Hopkins University', 'Cyber Security') 66
# ('Rutgers University, New Brunswick', 'Industrial Engineering') 66
# ('Delft University of Technology', 'Chemical Engineering') 66
# ('George Washington University', 'Electrical Engineering') 66
# ('Indiana University - Purdue University, Indianapolis', 'Computer Science') 65
# ('Florida International University, Miami', 'Information Systems') 64
# ('Purdue University, West Lafayette', 'Aerospace Engineering') 64
# ('State University of New York, Buffalo', 'Biotechnology') 62
# ('Lamar University', 'Computer Science') 62
# ('Indiana University - Purdue University, Indianapolis', 'Human Computer Interaction') 61
# ('Carnegie Mellon University', 'Human Computer Interaction') 60
# ('University of Colorado, Boulder', 'Engineering Management') 60
# ('Georgia Institute of Technology', 'Bioinformatics') 60
# ('Dalhousie University', 'Industrial Engineering') 58
# ('California State University, Fresno', 'Industrial Engineering') 58
# ('State University of New York, Buffalo', 'Engineering Management') 58
# ('New Jersey Institute of Technology', 'Cyber Security') 57
# ('State University of New York, Binghamton', 'Industrial Engineering') 56
# ('George Mason University', 'Telecommunications Engineering') 56
# ('Delft University of Technology', 'Embedded Systems') 54
# ('Florida Institute of Technology', 'Electrical Engineering') 54
# ('Georgia Institute of Technology', 'Finance') 52
# ('George Washington University', 'Business Analytics') 52
# ('Clemson University', 'Environmental Engineering') 52
# ('State University of New York, Stony Brook', 'EECS') 50
# ('Florida Institute of Technology', 'Mechanical Engineering') 50
# ('Lawrence Technological University', 'Mechanical Engineering') 49
# ('Rutgers University, New Brunswick', 'Biomedical Engineering') 48
# ('Eastern Michigan University', 'Computer Science') 48
# ('ETH Zurich', 'Computer Science') 48
# ('University of North Carolina, Charlotte', 'Engineering') 48
# ('Fairleigh Dickinson University', 'Electrical Engineering') 48
# ('Delft University of Technology', 'Computer Engineering') 46
# ('Purdue University, West Lafayette', 'Supply Chain Management') 46
# ('State University of New York, Buffalo', 'EECS') 46
# ('Florida State University', 'Electrical Engineering') 46
# ('University of North Carolina, Charlotte', 'Cyber Security') 46
# ('Bowling Green State University', 'Computer Science') 46
# ('Lawrence Technological University', 'Automotive Engineering') 45
# ('Florida Institute of Technology', 'Aerospace Engineering') 44
# ('San Jose State University', 'Data Analytics') 43
# ('Indiana University, Bloomington', 'Information Systems') 43
# ('Duke University', 'MIS') 42
# ('Florida International University, Miami', 'Construction Management') 42
# ('Kansas State University', 'Electrical Engineering') 42
# ('George Mason University', 'Telecommunication Engineering') 42
# ('Iowa State University', 'Aerospace Engineering') 41
# ('University of Maryland, College Park', 'Aerospace Engineering') 40
# ('State University of New York, Stony Brook', 'Biomedical Engineering') 40
# ('Columbia University', 'Computer Engineering') 40
# ('Johns Hopkins University', 'Biomedical Engineering') 39
# ('California State University, Fresno', 'Mechanical Engineering') 38
# ('George Mason University', 'MIS') 38
# ('Rutgers University, New Brunswick', 'Data Analytics') 38
# ('San Jose State University', 'Engineering Management') 38
# ('Lakehead University', 'Computer Science') 37
# ('Duke University', 'Data Science') 36
# ('Illinios Institute of Technology, Chicago', 'Manufacturing Engineering') 36
# ('Clemson University', 'Biomedical Engineering') 36
# ('Georgia Institute of Technology', 'Environmental Mining') 36
# ('New Jersey Institute of Technology', 'Chemical Engineering') 35
# ('George Mason University', 'Software Engineering') 34
# ('Columbia University', 'Engineering Management') 34
# ('Gannon University', 'Electrical Engineering') 34
# ('New Jersey Institute of Technology', 'Biomedical Engineering') 34
# ('Lawrence Technological University', 'Industrial Engineering') 34
# ('Purdue University, West Lafayette', 'Cyber Security') 34
# ('State University of New York, Albany', 'Information Science') 34
# ('Illinios Institute of Technology, Chicago', 'Biomedical Engineering') 34
# ('Embry Riddle Aeronautical University', 'Aerospace Engineering') 34
# ('Simon Fraser University', 'Computer Science') 34
# ('Indiana State University', 'Computer Science') 34
# ('Clemson University', 'Chemical and Petroleum Engineering') 32
# ('Duke University', 'Mechanical Engineering') 32
# ('Louisiana State University, Baton Rouge', 'Computer Science') 32
# ('Columbia University', 'Finance') 32
# ('California State University, Long Beach', 'Aerospace Engineering') 32
# ('Cleveland State University', 'Chemical Engineering') 32
# ('Indiana University, Bloomington', 'Information Science') 32
# ('Eindhoven University of Technology', 'Embedded Systems') 32
# ('George Washington University, Mount Vernon College', 'MIS') 30
# ('Columbia University', 'Biomedical Engineering') 30
# ('State University of New York, Buffalo', 'Aerospace Engineering') 30
# ('State University of New York, Buffalo', 'Information Systems') 30
# ('ETH Zurich', 'Mechanical Engineering') 30
# ('Illinios Institute of Technology, Chicago', 'EECS') 30
# ('Fairleigh Dickinson University', 'MIS') 30
# ('Drexel University', 'Computer Engineering') 30
# ('Rutgers University, New Brunswick', 'EECS') 30
# ('Illinois State University', 'Information Systems') 29
# ('New Jersey Institute of Technology', 'Software Engineering') 29
# ('Gannon University', 'Mechanical Engineering') 28
# ('New Jersey Institute of Technology', 'Telecommunications Engineering') 28
# ('Dalhousie University', 'Mechanical Engineering') 28
# ('Florida State University', 'Industrial Engineering') 26
# ('Louisiana Tech University', 'Computer Science') 26
# ('Johns Hopkins University', 'Robotics') 26
# ('San Jose State University', 'EECS') 26
# ('Georgia Institute of Technology', 'Biomedical Engineering') 26
# ('Florida Institute of Technology', 'Engineering Management') 26
# ('Eastern Michigan University', 'Mechanical Engineering') 26
# ('Lamar University', 'Mechanical Engineering') 26
# ('Iowa State University', 'Chemical Engineering') 25
# ('Johns Hopkins University', 'Mechanical Engineering') 24
# ('University of North Carolina, Charlotte', 'Health Informatics') 24
# ('University of Maryland, College Park', 'Transportation Engineering') 24
# ('Georgia Institute of Technology', 'Chemical Engineering') 24
# ('Harvard University', 'Computer Science') 24
# ('Carnegie Mellon University', 'Chemical and Petroleum Engineering') 24
# ('Florida Atlantic University', 'Computer Science') 24
# ('Columbia University', 'EECS') 24
# ('Florida International University, Miami', 'Electrical Engineering') 22
# ('Eastern Michigan University', 'Electrical Engineering') 22
# ('Fairleigh Dickinson University, Florham', 'Computer Science') 22
# ('Purdue University, West Lafayette', 'Chemical and Petroleum Engineering') 22
# ('Illinios Institute of Technology, Chicago', 'Telecommunication Engineering') 22
# ('Cleveland State University', 'Biomedical Engineering') 22
# ('San Jose State University', 'Civil Engineering') 21
# ('Lehigh University', 'Mechanical Engineering') 21
# ('San Jose State University', 'Mechanical Engineering') 21
# ('Carnegie Mellon University', 'Finance') 20
# ('New Jersey Institute of Technology', 'Electrical and Electronics Engineering') 20
# ('Lakehead University', 'Mechanical Engineering') 20
# ('Iowa State University', 'EECS') 20
# ('Illinios Institute of Technology, Chicago', 'Environmental Mining') 20
# ('Illinios Institute of Technology, Chicago', 'Finance') 20
# ('Duke University', 'Electrical Engineering') 20
# ('Carnegie Mellon University', 'Engineering Management') 20
# ('Eastern Michigan University', 'Information Systems') 20
# ('New Jersey Institute of Technology', 'Telecommunication Engineering') 19
# ('Johns Hopkins University', 'Information Systems') 19
# ('Duke University', 'Industrial Engineering') 18
# ('George Washington University, Mount Vernon College', 'Electrical Engineering') 18
# ('University of Maryland, College Park', 'Bioengineering') 18
# ('State University of New York, Buffalo', 'Bioinformatics') 18
# ('Drexel University', 'Cyber Security') 18
# ('Lamar University', 'Chemical and Petroleum Engineering') 18
# ('University of Maryland, College Park', 'Environmental Engineering') 18
# ('Rutgers University, New Brunswick', 'Chemical and Petroleum Engineering') 18
# ('Rutgers University, New Brunswick', 'Civil Engineering') 18
# ('State University of New York, Stony Brook', 'MIS') 18
# ('Florida State University', 'Mechanical Engineering') 18
# ('Eastern Michigan University', 'Engineering Management') 18
# ('New Jersey Institute of Technology', 'Bioinformatics') 17
# ('Indiana University - Purdue University, Indianapolis', 'Health Informatics') 17
# ('Indiana University, Bloomington', 'Cyber Security') 17
# ('Carnegie Mellon University', 'Civil Engineering') 16
# ('Grand Valley State University', 'Mechanical Engineering') 16
# ('San Jose State University', 'MIS') 16
# ('Drexel University', 'Telecommunication Engineering') 16
# ('Rutgers University, New Brunswick', 'Information Science') 16
# ('Illinios Institute of Technology, Chicago', 'Industrial Engineering') 16
# ('State University of New York, Buffalo', 'Pharmacy') 16
# ('University of North Carolina, Charlotte', 'Finance') 16
# ('Illinios Institute of Technology, Chicago', 'Engineering Management') 16
# ('Indiana University, Bloomington', 'Bioinformatics') 16
# ('Georgia Institute of Technology', 'MIS') 16
# ('Delft University of Technology', 'Data Science') 16
# ('Georgia State University', 'Data Science') 16
# ('Florida International University, Miami', 'Engineering Management') 16
# ('Lehigh University', 'Computer Science') 16
# ('Indiana University - Purdue University, Indianapolis', 'Electrical Engineering') 15
# ('Lawrence Technological University', 'Computer Science') 15
# ('Kansas State University', 'Civil Engineering') 15
# ('Lehigh University', 'Industrial Engineering') 15
# ('Illinios Institute of Technology, Chicago', 'Aerospace Engineering') 14
# ('Rutgers University, New Brunswick', 'Engineering Management') 14
# ('Lamar University', 'Electrical Engineering') 14
# ('Purdue University, West Lafayette', 'Management') 14
# ('University of Colorado, Boulder', 'Aerospace Engineering') 14
# ('Drexel University', 'EECS') 14
# ('Indiana University - Purdue University, Indianapolis', 'Biomedical Engineering') 14
# ('Dalhousie University', 'Chemical Engineering') 14
# ('California State University, Fresno', 'Civil Engineering') 14
# ('Georgia Institute of Technology', 'Environmental Engineering') 14
# ('Florida International University, Miami', 'Data Science') 14
# ('Florida Institute of Technology', 'Civil Engineering') 14
# ('Florida State University', 'MIS') 14
# ('Florida State University', 'Civil Engineering') 14
# ('Kansas State University', 'Mechanical Engineering') 13
# ('Lawrence Technological University', 'Civil Engineering') 13
# ('Clemson University', 'Chemical Engineering') 12
# ('Rutgers University, New Brunswick', 'MIS') 12
# ('Rutgers University, New Brunswick', 'Environmental Engineering') 12
# ('Illinios Institute of Technology, Chicago', 'Artificial Intelligence') 12
# ('Illinios Institute of Technology, Chicago', 'Information Systems') 12
# ('Georgia Institute of Technology', 'Bioengineering') 12
# ('George Mason University', 'Bioinformatics') 12
# ('Fordham University', 'Business Analytics') 12
# ('Columbia University', 'Civil Engineering') 12
# ('Cleveland State University', 'Environmental Engineering') 12
# ('State University of New York, Binghamton', 'EECS') 12
# ('Clemson University', 'Bioengineering') 12
# ('Georgia Institute of Technology', 'Telecommunication Engineering') 12
# ('Delft University of Technology', 'Computer Science') 12
# ('University of Maryland, College Park', 'Chemical Engineering') 12
# ('Georgetown University', 'Computer Science') 12
# ('Purdue University, West Lafayette', 'MIS') 12
# ('California State University, Long Beach', 'EECS') 12
# ('University of Colorado, Boulder', 'Environmental Engineering') 12
# ('Lehigh University', 'Chemical Engineering') 11
# ('New Jersey Institute of Technology', 'EECS') 11
# ('Louisiana State University, Baton Rouge', 'Chemical Engineering') 11
# ('Cleveland State University', 'MIS') 10
# ('State University of New York, Buffalo', 'Business Analytics') 10
# ('Duke University', 'Management Science and Engineering') 10
# ('Lamar University', 'Engineering Management') 10
# ('Columbia University', 'MIS') 10
# ('Lehigh University', 'Electrical Engineering') 10
# ('State University of New York, Stony Brook', 'Cyber Security') 10
# ('Rutgers University, New Brunswick', 'Pharmacy') 10
# ('Florida International University, Miami', 'Telecommunication Engineering') 10
# ('University of North Carolina, Charlotte', 'Information Systems') 10
# ('University of North Carolina, Charlotte', 'Bioinformatics') 10
# ('Fairleigh Dickinson University', 'Information Systems') 10
# ('Johns Hopkins University', 'Electrical Engineering') 9
# ('New Jersey Institute of Technology', 'Business Analytics') 9
# ('New Jersey Institute of Technology', 'Environmental Engineering') 9
# ('Illinois State University', 'MIS') 9
# ('San Jose State University', 'Aerospace Engineering') 9
# ('University of Colorado, Boulder', 'MIS') 8
# ('State University of New York, Buffalo', 'Architecture') 8
# ('Drexel University', 'Biotechnology') 8
# ('Drexel University', 'Civil Engineering') 8
# ('Lehigh University', 'Civil Engineering') 8
# ('State University of New York, Buffalo', 'Information Technology') 8
# ('Clemson University', 'Aerospace Engineering') 8
# ('State University of New York, Stony Brook', 'Computer Engineering') 8
# ('Fordham University', 'Computer Science') 8
# ('Louisiana Tech University', 'Mechanical Engineering') 8
# ('Rutgers University, New Brunswick', 'Biotechnology') 8
# ('University of North Carolina, Charlotte', 'Industrial Engineering') 8
# ('Cleveland State University', 'Industrial Engineering') 8
# ('Columbia University', 'Chemical Engineering') 8
# ('Rutgers University, New Brunswick', 'Bioinformatics') 8
# ('Drexel University', 'MIS') 8
# ('George Washington University, Mount Vernon College', 'Engineering Management') 8
# ('Duke University', 'EECS') 8
# ('Illinios Institute of Technology, Chicago', 'Chemical and Petroleum Engineering') 8
# ('Johns Hopkins University', 'Civil Engineering') 7
# ('Louisiana Tech University', 'Electrical Engineering') 7
# ('San Jose State University', 'Industrial and Systems Engineering') 7
# ('State University of New York, Buffalo', 'Telecommunication Engineering') 6
# ('University of Colorado, Boulder', 'Data Science') 6
# ('Boise State University', 'Computer Science') 6
# ('Drexel University', 'Environmental Engineering') 6
# ('Columbia University', 'Biotechnology') 6
# ('Grand Valley State University', 'Manufacturing Engineering') 6
# ('Florida State University', 'Biomedical Engineering') 6
# ('Florida International University, Miami', 'Cyber Security') 6
# ('Florida International University, Miami', 'Biomedical Engineering') 6
# ('Lakehead University', 'Civil Engineering') 6
# ('Delft University of Technology', 'Biomedical Engineering') 6
# ('Columbia University', 'Cyber Security') 6
# ('Georgia Institute of Technology', 'Biotechnology') 6
# ('Louisiana State University, Baton Rouge', 'Mechanical Engineering') 6
# ('Louisiana Tech University', 'Biomedical Engineering') 6
# ('Columbia University', 'Architecture') 6
# ('Carnegie Mellon University', 'Biotechnology') 6
# ('San Jose State University', 'Biotechnology') 6
# ('Harvard University', 'Health Data Science') 5
# ('Georgetown University', 'Data Science') 5
# ('George Washington University, Virginia Campus', 'Engineering Management') 5
# ('Governors State University', 'MIS') 5
# ('Kent State University', 'Public Health') 5
# ('University of Hartford', 'Mechanical Engineering') 5
# ('Iowa State University', 'Bioinformatics') 5
# ('California State University, Long Beach', 'Cyber Security') 4
# ('Gannon University', 'Computer Science') 4
# ('Florida State University', 'Chemical and Petroleum Engineering') 4
# ('California State University, Long Beach', 'MIS') 4
# ('California State University, Long Beach', 'Engineering Management') 4
# ('Columbia University', 'Chemical and Petroleum Engineering') 4
# ('Florida Institute of Technology', 'Industrial Engineering') 4
# ('Drexel University', 'Mechanical Engineering') 4
# ('Drexel University', 'Environmental Mining') 4
# ('Georgia Institute of Technology', 'Engineering Management') 4
# ('Delft University of Technology', 'Robotics') 4
# ('Delft University of Technology', 'Architecture') 4
# ('State University of New York, Buffalo', 'Cyber Security') 4
# ('Georgia Institute of Technology', 'Machine Learning') 4
# ('Georgia Institute of Technology', 'Information Technology') 4
# ('State University of New York, Albany', 'Electrical Engineering') 4
# ('Rutgers University, New Brunswick', 'Toxicology') 4
# ('State University of New York, Stony Brook', 'Biotechnology') 4
# ('Lawrence Technological University', 'Engineering Management') 4
# ('Kettering University, Flint', 'Automotive Engineering') 4
# ('Georgia State University', 'Public Health') 4
# ('Lakehead University', 'MBA') 3
# ('San Jose State University', 'Information Technology') 3
# ('George Washington University, Virginia Campus', 'Telecommunication Engineering') 3
# ('New Jersey Institute of Technology', 'Architecture') 3
# ('George Washington University, Virginia Campus', 'Information Systems') 3
# ('Lehigh University', 'Management Science and Engineering') 3
# ('Harvard University', 'Architecture') 3
# ('Lamar University', 'Chemical Engineering') 3
# ('University of Pittsburgh, Johnstown', 'Telecommunication Engineering') 3
# ('Johns Hopkins University', 'EECS') 3
# ('Iowa State University', 'Environmental Engineering') 3
# ('Iowa State University', 'Engineering Management') 3
# ('George Washington University, Virginia Campus', 'EECS') 2
# ('Kansas State University', 'EECS') 2
# ('Johns Hopkins University', 'Chemical Engineering') 2
# ('Lehigh University', 'Manufacturing Engineering') 2
# ('Louisiana State University, Baton Rouge', 'Automotive Engineering') 2
# ('Illinois State University', 'Information Technology') 2
# ('Harvard University', 'Bioinformatics') 2
# ('South Dakota School of Mines and Technology', 'Electrical Engineering') 2
# ('University of Pittsburgh, Johnstown', 'Computer Science') 2
# ('University of Pittsburgh, Johnstown', 'Electrical Engineering') 2
# ('George Washington University, Virginia Campus', 'Bioinformatics') 2

# %% [markdown]
# ## Combining TOFEL/IELTS and normalising them

# %%
def convert_to_ielts(score):
    if pd.notnull(score):
        if score == 0.0:
            return None
        if 118 <= score <= 120:
            return 9
        elif 115 <= score <= 117:
            return 8.5
        elif 110 <= score <= 114:
            return 8
        elif 102 <= score <= 109:
            return 7.5
        elif 94 <= score <= 101:
            return 7
        elif 79 <= score <= 93:
            return 6.5
        elif 60 <= score <= 78:
            return 6
        elif 46 <= score <= 59:
            return 5.5
        elif 35 <= score <= 45:
            return 5
        elif 32 <= score <= 34:
            return 4.5
        else:
            return 4
    else:
        return None

# %%
df['TOEFL'] = df['TOEFL'].apply(convert_to_ielts)
df['TOEFL/IELTS'] = df['TOEFL'].combine_first(df['IELTS'])
df.drop(columns=['TOEFL', 'IELTS'], inplace=True, axis=1)

# %% [markdown]
# ## Encoding University Name and Target Majors

# %%
# Create LabelEncoder instances for University and Target Major
university_encoder = LabelEncoder()
major_encoder = LabelEncoder()
season_encoder = LabelEncoder()

# Fit the LabelEncoders to the University and Target Major columns
university_encoder.fit(df['University'])
major_encoder.fit(df['Target Major'])
season_encoder.fit(df['Season'])

df_tranformed = df.copy()
df_tranformed['University'] = university_encoder.transform(df['University'])
df_tranformed['Target Major'] = major_encoder.transform(df['Target Major'])
df_tranformed['Season'] = season_encoder.transform(df['Season'])
df_tranformed = df_tranformed.drop(columns=['UG College', 'UG Major', 'Year'])

# %%
df_tranformed.head()
# Out:
#    University  Status  Target Major  GRE Verbal  GRE Quantitative  \
# 0           1       0            16       135.0             146.0
# 1           1       1            16       170.0             147.0
# 3           1       0            16       148.0             133.0
# 4           1       1            16       147.0             136.0
# 5           1       1            16       154.0             144.0
#
#    GRE Writing  GRE Total    GPA  Papers Work Exp  Season  TOEFL/IELTS
# 0          3.0      281.0  2.240     0.0        0       0          6.0
# 1          4.0      317.0  2.992     0.0        0       1          7.0
# 3          3.0      281.0  2.892     0.0        0       0          6.5
# 4          2.0      283.0  2.800     0.0        0       1          6.0
# 5          3.5      298.0  2.804     0.0        0       0          7.0

# %%
df_tranformed['Status'].value_counts()
# Out:
# Status
# 1    20567
# 0    11350
# Name: count, dtype: int64

# %% [markdown]
# ## Splitting Train and Test

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

import matplotlib.pyplot as plt
X_train, X_test, y_train, y_test = train_test_split(df_tranformed.drop(columns=['Status']), df_tranformed['Status'], test_size=0.2, random_state=42)

# Postive smallest count of Status

positive_class = y_train.value_counts().idxmin()
negative_class = y_train.value_counts().idxmax()

print(f'Positive Class: {positive_class}')
print(f'Negative Class: {negative_class}', '\n')
# Out:
# Positive Class: 0
# Negative Class: 1

# %%
from sklearn.model_selection import GridSearchCV

# %%
def get_results(model,X_test, y_test):
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    return accuracy, precision, recall

# %%
def confusion_matrix_display(y_test, y_pred):
    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
    disp.plot()
    plt.show()

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## Default params

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)

accuracy, precision, recall = get_results(lr, X_test, y_test)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')

confusion_matrix_display(y_test, lr.predict(X_test))
# Out:
# Accuracy: 0.6495927318295739
# Precision: 0.650581578120088
# Recall: 0.9966289429328197

# %% [markdown]
# ## With GridSearch

# %%
# from sklearn.metrics import confusion_matrix
# from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# import matplotlib.pyplot as plt
# X_train, X_test, y_train, y_test = train_test_split(df_tranformed.drop(columns=['Status']), df_tranformed['Status'], test_size=0.2, random_state=42)

# # Postive smallest count of Status

# positive_class = y_train.value_counts().idxmin()
# negative_class = y_train.value_counts().idxmax()

# print(f'Positive Class: {positive_class}')
# print(f'Negative Class: {negative_class}', '\n')

# model = LogisticRegression()

# parameters = {
#     'penalty': ['l1', 'l2', 'elasticnet', 'none'],
#     'dual': [True, False],
#     'tol': [1e-4, 1e-3, 1e-2],
#     'C': [1.0, 0.1, 0.01],
#     'fit_intercept': [True, False],
#     'intercept_scaling': [1, 2, 3],
#     'class_weight': ['balanced', {0: 1, 1: 9}, {0: 5, 1: 5}, {0: 9, 1: 1}],
# }

# model = LogisticRegression()

# clf = GridSearchCV(model, parameters, scoring='accuracy')
# clf.fit(X_train, y_train)

# print(f'Best Parameters: {clf.best_params_}')

# best_model_logistic = clf.best_estimator_
# best_model_logistic.fit(X_train, y_train)

# y_pred = best_model_logistic.predict(X_test)
# accuracy = accuracy_score(y_test, y_pred)
# precision = precision_score(y_test, y_pred)
# recall = recall_score(y_test, y_pred)

# print(f'Accuracy: {accuracy}')
# print(f'Precision: {precision}')
# print(f'Recall: {recall}', '\n')

# cm = confusion_matrix(y_test, y_pred)
# disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=best_model_logistic.classes_)
# disp.plot();

# %% [markdown]
# ## RidgeClassifier

# %%
from sklearn.linear_model import RidgeClassifier

# %% [markdown]
# ## With default params

# %%
rc = RidgeClassifier()
rc.fit(X_train, y_train)

accuracy, precision, recall = get_results(rc, X_test, y_test)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')

confusion_matrix_display(y_test, rc.predict(X_test))
# Out:
# Accuracy: 0.6495927318295739
# Precision: 0.6512950094756791
# Recall: 0.9930170960751264

# %% [markdown]
# ## With GridSearch

# %%
# from sklearn.linear_model import RidgeClassifier

# ridgeClassifierModel = RidgeClassifier()

# parameters = {
#     'alpha': [1.0, 0.1, 0.01, 0.001, 0.0001],
#     'fit_intercept': [True, False],
#     'copy_X': [True, False],
#     'max_iter': [100, 200, 300, 400, 500],
#     'tol': [1e-4, 1e-3, 1e-2, 1e-1, 1],
#     # 'class_weight': ['balanced', {0: 1, 1: 9}, {0: 5, 1: 5}, {0: 9, 1: 1}, None],
#     # 'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga'],
# }

# clf = GridSearchCV(ridgeClassifierModel, parameters, scoring='accuracy')
# clf.fit(X_train, y_train)

# print(f'Best Parameters: {clf.best_params_}')

# best_model_eidge = RidgeClassifier(**clf.best_params_)
# best_model_eidge.fit(X_train, y_train)

# y_pred = best_model_eidge.predict(X_test)
# accuracy = accuracy_score(y_test, y_pred)
# precision = precision_score(y_test, y_pred)
# recall = recall_score(y_test, y_pred)

# print(f'Accuracy: {accuracy}')
# print(f'Precision: {precision}')
# print(f'Recall: {recall}', '\n')

# print(f'Best Parameters: {clf.best_params_}')

# cm = confusion_matrix(y_test, y_pred)
# disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=best_model_eidge.classes_)
# disp.plot();

# %% [markdown]
# ## SGDClassifier

# %%
from sklearn.linear_model import SGDClassifier

# %% [markdown]
# ## Withy default params

# %%
sgdc = SGDClassifier()
sgdc.fit(X_train, y_train)

accuracy, precision, recall = get_results(sgdc, X_test, y_test)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')

confusion_matrix_display(y_test, sgdc.predict(X_test))
# Out:
# Accuracy: 0.3494674185463659
# Precision: 0.0
# Recall: 0.0

# %%
# from sklearn.experimental import enable_halving_search_cv
# from sklearn.model_selection import HalvingGridSearchCV

# sgdClassifier = SGDClassifier()

# parameters = {
#     'loss': ['hinge', 'log', 'modified_huber', 'squared_hinge', 'perceptron'],
#     'penalty': ['l2', 'l1', 'elasticnet'],
#     'alpha': [1e-4, 1e-3, 1e-2, 1e-1, 1],
#     'l1_ratio': [0.15, 0.1, 0.05, 0.01, 0.001, 1.0],
#     'tol': [1e-4, 1e-3, 1e-2, 1e-1, 1],
#     # 'shuffle': [True, False],
#     'epsilon': [0.1, 0.01, 0.001, 0.0001],
#     'learning_rate': ['optimal', 'constant', 'invscaling', 'adaptive'],
#     # 'eta0': [0.1, 0.01, 0.001, 0.0001],
#     # 'power_t': [0.1, 0.01, 0.001, 0.0001],
# }

# clf = HalvingGridSearchCV(sgdClassifier, parameters, scoring='accuracy', max_resources=50)
# clf.fit(X_train, y_train)

# print(f'Best Parameters: {clf.best_params_}')

# best_model_sgd = clf.best_estimator_
# # best_model_sgd.fit(X_train, y_train)

# y_pred = best_model_sgd.predict(X_test)
# accuracy = accuracy_score(y_test, y_pred)
# precision = precision_score(y_test, y_pred)
# recall = recall_score(y_test, y_pred)

# print(f'Accuracy: {accuracy}')
# print(f'Precision: {precision}')
# print(f'Recall: {recall}', '\n')

# print(f'Best Parameters: {clf.best_params_}')

# cm = confusion_matrix(y_test, y_pred)
# disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=best_model_sgd.classes_)
# disp.plot();

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## With default Params

# %%
dtc = DecisionTreeClassifier()
dtc.fit(X_train, y_train)

accuracy, precision, recall = get_results(dtc, X_test, y_test)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')

confusion_matrix_display(y_test, dtc.predict(X_test))
# Out:
# Accuracy: 0.9096177944862155
# Precision: 0.9312590448625181
# Recall: 0.9296893811702384

# %% [markdown]
# # Perceptron

# %% [markdown]
# ## with default params

# %%
from sklearn.linear_model import Perceptron

perc = Perceptron()
perc.fit(X_train, y_train)

accuracy, precision, recall = get_results(perc, X_test, y_test)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')

confusion_matrix_display(y_test, perc.predict(X_test))
# Out:
# Accuracy: 0.6475563909774437
# Precision: 0.6502922129205497
# Recall: 0.9913315675415363

# %% [markdown]
# # PassiveAggressiveClassifier

# %% [markdown]
# ## With default params

# %%
from sklearn.linear_model import PassiveAggressiveClassifier

pac = PassiveAggressiveClassifier()
pac.fit(X_train, y_train)

accuracy, precision, recall = get_results(pac, X_test, y_test)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')

confusion_matrix_display(y_test, pac.predict(X_test))
# Out:
# Accuracy: 0.6505325814536341
# Precision: 0.6505325814536341
# Recall: 1.0

# %% [markdown]
# # SVM

# %% [markdown]
# ## With default params

# %%
from sklearn import svm

svmc = svm.SVC()
svmc.fit(X_train, y_train)

accuracy, precision, recall = get_results(svmc, X_test, y_test)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')

confusion_matrix_display(y_test, svmc.predict(X_test))
# Out:
# Accuracy: 0.6505325814536341
# Precision: 0.6505325814536341
# Recall: 1.0

# %% [markdown]
# # Gaussian Process --- Not running on local xD

# %%
# from sklearn import gaussian_process

# gpc = gaussian_process.GaussianProcessClassifier()
# gpc.fit(X_train, y_train)

# accuracy, precision, recall = get_results(gpc, X_test, y_test)
# print(f'Accuracy: {accuracy}')
# print(f'Precision: {precision}')
# print(f'Recall: {recall}')

# confusion_matrix_display(y_test, gpc.predict(X_test))

# %% [markdown]
# # Ensembles

# %% [markdown]
# ## GradientBoostingClassifier

# %% [markdown]
# ### With default params

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbc = GradientBoostingClassifier()
gbc.fit(X_train, y_train)

accuracy, precision, recall = get_results(gbc, X_test, y_test)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')

confusion_matrix_display(y_test, gbc.predict(X_test))
# Out:
# Accuracy: 0.7037907268170426
# Precision: 0.7059359067734887
# Recall: 0.9335420178184445

# %% [markdown]
# ## HistGradientBoostingClassifier

# %% [markdown]
# ### With default params

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

hgbc = HistGradientBoostingClassifier()
hgbc.fit(X_train, y_train)

accuracy, precision, recall = get_results(hgbc, X_test, y_test)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')

confusion_matrix_display(y_test, hgbc.predict(X_test))

# with categorical features

hgbcc = HistGradientBoostingClassifier(categorical_features=[0, 1])
hgbcc.fit(X_train, y_train)

accuracy, precision, recall = get_results(hgbcc, X_test, y_test)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')

confusion_matrix_display(y_test, hgbcc.predict(X_test))
# Out:
# Accuracy: 0.762687969924812
# Precision: 0.7664646464646465
# Recall: 0.9135564652058753
# Accuracy: 0.7913533834586466
# Precision: 0.8130965593784684
# Recall: 0.8820130026486876

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Using default params

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

accuracy, precision, recall = get_results(rfc, X_test, y_test)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')

confusion_matrix_display(y_test, rfc.predict(X_test))

# extremely randomized trees

from sklearn.ensemble import ExtraTreesClassifier

etc = ExtraTreesClassifier()
etc.fit(X_train, y_train)

accuracy, precision, recall = get_results(etc, X_test, y_test)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')

confusion_matrix_display(y_test, etc.predict(X_test))
# Out:
# Accuracy: 0.9166666666666666
# Precision: 0.9134505594884677
# Recall: 0.963159162051529
# Accuracy: 0.9161967418546366
# Precision: 0.9115104640582348
# Recall: 0.9648446905851192

# %% [markdown]
# ## Baggign meta-estimator

# %% [markdown]
# ### With default params

# %%
from sklearn.ensemble import BaggingClassifier

bc = BaggingClassifier()
bc.fit(X_train, y_train)

accuracy, precision, recall = get_results(bc, X_test, y_test)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')

confusion_matrix_display(y_test, bc.predict(X_test))
# Out:
# Accuracy: 0.9083646616541353
# Precision: 0.9302942595272552
# Recall: 0.9287262220081869

# %% [markdown]
# ## Voting Classifier

# %% [markdown]
# ### With default params

# %%
from sklearn.ensemble import VotingClassifier

cl1 = RandomForestClassifier()
cl2 = ExtraTreesClassifier()
cl3 = BaggingClassifier()
# cl4 = DecisionTreeClassifier()

vc = VotingClassifier(estimators=[
    ('rfc', cl1), 
    ('etc', cl2), 
    ('bc', cl3), 
    # ('dtc', cl4)
    ], voting='soft')
vc.fit(X_train, y_train)

accuracy, precision, recall = get_results(vc, X_test, y_test)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')

confusion_matrix_display(y_test, vc.predict(X_test))

# With weights

vcw = VotingClassifier(estimators=[
    ('rfc', cl1), 
    ('etc', cl2), 
    ('bc', cl3), 
    # ('dtc', cl4)
    ], voting='soft', weights=[2, 2, 2])
vcw.fit(X_train, y_train)

accuracy, precision, recall = get_results(vcw, X_test, y_test)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')

confusion_matrix_display(y_test, vcw.predict(X_test))
# Out:
# Accuracy: 0.9226190476190477
# Precision: 0.9197063546685019
# Recall: 0.9653262701661449
# Accuracy: 0.9246553884711779
# Precision: 0.9197530864197531
# Recall: 0.9686973272333254

# %% [markdown]
# ## Stacking Classifier

# %% [markdown]
# ### With default params

# %%
from sklearn.ensemble import StackingClassifier

estimators = [
    ('rf', RandomForestClassifier()),
    ('et', ExtraTreesClassifier()),
    ('bc', BaggingClassifier())
]

stack1 = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())
stack1.fit(X_train, y_train)

stack2 = StackingClassifier(estimators=estimators, final_estimator=DecisionTreeClassifier())
stack2.fit(X_train, y_train)

stack3 = StackingClassifier(estimators=estimators, final_estimator=RandomForestClassifier())
stack3.fit(X_train, y_train)

stack4 = StackingClassifier(estimators=estimators, final_estimator=ExtraTreesClassifier())
stack4.fit(X_train, y_train)

stack5 = StackingClassifier(estimators=estimators, final_estimator=BaggingClassifier())
stack5.fit(X_train, y_train)

from sklearn.svm import SVC
from sklearn.calibration import CalibratedClassifierCV
stack6 = StackingClassifier(estimators=estimators, final_estimator=CalibratedClassifierCV(SVC(probability=True)))
stack6.fit(X_train, y_train)

y_pred_proba1 = stack1.predict_proba(X_test)[:, 1]
y_pred_proba2 = stack2.predict_proba(X_test)[:, 1]
y_pred_proba3 = stack3.predict_proba(X_test)[:, 1]
y_pred_proba4 = stack4.predict_proba(X_test)[:, 1]
y_pred_proba5 = stack5.predict_proba(X_test)[:, 1]
y_pred_proba6 = stack6.predict_proba(X_test)[:, 1]

from sklearn.metrics import roc_curve, RocCurveDisplay

fpr1, tpr1, _ = roc_curve(y_test, y_pred_proba1)
fpr2, tpr2, _ = roc_curve(y_test, y_pred_proba2)
fpr3, tpr3, _ = roc_curve(y_test, y_pred_proba3)
fpr4, tpr4, _ = roc_curve(y_test, y_pred_proba4)
fpr5, tpr5, _ = roc_curve(y_test, y_pred_proba5)
fpr6, tpr6, _ = roc_curve(y_test, y_pred_proba6)

plt.figure(figsize=(10, 10))
plt.plot(fpr1, tpr1, color="red" , label='Logistic Regression')
plt.plot(fpr2, tpr2, color="blue", label='Decision Tree')
plt.plot(fpr3, tpr3, color="green", label='Random Forest')
plt.plot(fpr4, tpr4, color="red", label='Extra Trees')
plt.plot(fpr5, tpr5, color="yellow", label='Bagging Classifier')
plt.plot(fpr6, tpr6, color="cyan", label='SVM')
plt.plot([0, 1], [0, 1], 'k--')

# Concolusion: Logistic Regression is the best last_estimator
# Out:
# Accuracy: 0.9212092731829574
# Precision: 0.9214780600461894
# Recall: 0.9607512641464002

# %% [markdown]
# ## AdaBooster

# %%
from sklearn.ensemble import AdaBoostClassifier

abc = AdaBoostClassifier(learning_rate=0.001, n_estimators=100, random_state=42, algorithm='SAMME')
abc.fit(X_train, y_train)

accuracy, precision, recall = get_results(abc, X_test, y_test)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')

confusion_matrix_display(y_test, abc.predict(X_test))
# Out:
# Accuracy: 0.6505325814536341
# Precision: 0.6505325814536341
# Recall: 1.0

# %% [markdown]
# ## Neural Networs

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=10000, activation='relu', solver='adam', random_state=42, learning_rate='constant', learning_rate_init=0.0001)
mlp.fit(X_train, y_train)

accuracy, precision, recall = get_results(mlp, X_test, y_test)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')

confusion_matrix_display(y_test, mlp.predict(X_test))
# Out:
# Accuracy: 0.6441102756892231
# Precision: 0.6642794759825328
# Recall: 0.9157235733204913

# %% [markdown]
# # ROC Curves without GridSearch

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 15))

y_pred_proba = lr.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)  # Restricted for binary classification, Ideal for us
plt.plot(fpr, tpr, color='red', label='Logistic Regression')

y_pred_proba = rc.decision_function(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)  # Restricted for binary classification, Ideal for us
plt.plot(fpr, tpr, color='blue', label='Ridge Classifier')

y_pred_proba = sgdc.decision_function(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)  # Restricted for binary classification, Ideal for us
plt.plot(fpr, tpr, color='orange', label='SGD Classifier')

y_pred_proba = perc.decision_function(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)  # Restricted for binary classification, Ideal for us
plt.plot(fpr, tpr, color='purple', label='Perceptron')

y_pred_proba = pac.decision_function(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)  # Restricted for binary classification, Ideal for us
plt.plot(fpr, tpr, color='black', label='Passive Aggressive Classifier')

y_pred_proba = dtc.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)  # Restricted for binary classification, Ideal for us
plt.plot(fpr, tpr, color='green', label='Decision Tree Classifier')

y_pred_proba = svmc.decision_function(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)  # Restricted for binary classification, Ideal for us
plt.plot(fpr, tpr, color='#25095a', label='SVM Classifier')

# y_pred_proba = gpc.predict_proba(X_test)[:, 1]
# fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)  # Restricted for binary classification, Ideal for us
# plt.plot(fpr, tpr, color='#044c4b', label='Gaussian Process Classifier')

y_pred_proba = gbc.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)  # Restricted for binary classification, Ideal for us
plt.plot(fpr, tpr, color='#f0134d', label='Gradient Boosting Classifier')

y_pred_proba = hgbc.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)  # Restricted for binary classification, Ideal for us
plt.plot(fpr, tpr, color='#ea07f7', label='Hist Gradient Boosting Classifier')

y_pred_proba = hgbcc.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)  # Restricted for binary classification, Ideal for us
plt.plot(fpr, tpr, color='#f7b307', label='Hist Gradient Boosting Classifier with Categorical Features')

y_pred_proba = rfc.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)  # Restricted for binary classification, Ideal for us
plt.plot(fpr, tpr, color='#fd8116', label='Random Forest Classifier')

y_pred_proba = etc.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)  # Restricted for binary classification, Ideal for us
plt.plot(fpr, tpr, color='#690091', label='Extra Trees Classifier')

# y_pred_proba = bc.predict_proba(X_test)[:, 1]
# fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)  # Restricted for binary classification, Ideal for us
# plt.plot(fpr, tpr, color='#914900', label='Bagging Classifier')

# y_pred_proba = vc.predict_proba(X_test)[:, 1]
# fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
# plt.plot(fpr, tpr, color='#e92874', label='Voting Classifier')

y_pred_proba = vcw.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
plt.plot(fpr, tpr, color='#137e40', label='Voting Classifier with Weights')

y_pred_proba = stack1.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
plt.plot(fpr, tpr, color='#ff3e3e', label='Stacking Classifier')

y_pred_proba = abc.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
plt.plot(fpr, tpr, color='#00cafe', label='AdaBoost Classifier')

y_pred_proba = mlp.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
plt.plot(fpr, tpr, color='#fe9a00', label='MLP Classifier')

plt.plot([0, 1], [0, 1], 'k--', label='Random guess')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %% [markdown]
# # ROC Curvs with GridSearch

# %%
# from sklearn.metrics import roc_curve, roc_auc_score
# import matplotlib.pyplot as plt

# y_pred_proba = best_model_logistic.predict_proba(X_test)[:, 1]
# fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)  # Restricted for binary classification, Ideal for us
# plt.plot(fpr, tpr, color='red', label='Logistic Regression')

# y_pred_proba = best_model_eidge.decision_function(X_test)
# fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)  # Restricted for binary classification, Ideal for us
# plt.plot(fpr, tpr, color='blue', label='Ridge Classifier')

# y_pred_proba = best_model_sgd.decision_function(X_test)
# fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)  # Restricted for binary classification, Ideal for us
# plt.plot(fpr, tpr, color='orange', label='SGD Classifier')

# y_pred_proba = dtc.predict_proba(X_test)[:, 1]
# fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)  # Restricted for binary classification, Ideal for us
# plt.plot(fpr, tpr, color='green', label='Decision Tree Classifier')

# plt.plot([0, 1], [0, 1], 'k--', label='Random guess')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('ROC Curve')
# plt.legend()
# plt.show()
